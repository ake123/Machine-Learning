# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlrd
# %matplotlib inline

# %%
df = pd.read_excel("ConcreteD.xls","Sheet1")

# %%
df1=df.head()
df1
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age (day)  Concrete compressive strength
# 0            1040.0           676.0         28                      79.986111
# 1            1055.0           676.0         28                      61.887366
# 2             932.0           594.0        270                      40.269535
# 3             932.0           594.0        365                      41.052780
# 4             978.4           825.5        360                      44.296075

# %%
df['Concrete compressive strength'].hist(bins='sqrt')

# %%
df.plot.area()

# %%
df.plot(kind ='hist',bins=40)

# %%
def draw_histograms(df, variables, n_rows, n_cols):
    fig=plt.figure(figsize=(12,6))
    for i, var_name in enumerate(variables):
        ax=fig.add_subplot(n_rows,n_cols,i+1)
        df[var_name].hist(bins='scott',ax=ax)
        ax.set_title(var_name+" Distribution")
    fig.tight_layout()  # Improves appearance a bit.
    plt.show()
#test = pd.DataFrame(np.random.randn(30, 9), columns=map(str, range(9)))
draw_histograms(df, df.columns, 3, 3)
plt.show()

# %%
import matplotlib.pyplot
import pylab
#df = pd.read_excel("Concrete_Data.xls","Sheet1")
def draw_scatterplot(df, variables, n_rows, n_cols):
    fig=plt.figure(figsize=(12,6))
    for i, var_name in enumerate(variables):
        a=df['Cement']
        y=df['Concrete compressive strength']
        ax=fig.add_subplot(n_rows,n_cols,i+1)
        matplotlib.pyplot.scatter(i,y)
        ax.set_title(var_name+" Distribution")
        #df[var_name].scatter(y,ax=ax)
    fig.tight_layout()  # Improves appearance a bit.
    matplotlib.pyplot.show()
    #plt.show()
#test = pd.DataFrame(np.random.randn(30, 9), columns=map(str, range(9)))
draw_scatterplot(df, df.columns, 3, 3)
plt.show()
#a=df['Cement']
#print x
#y=df['Concrete compressive strength']
#print y
#matplotlib.pyplot.scatter(a,y)
#matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d72359fd7018> in <module>()
#      15     #plt.show()
#      16 #test = pd.DataFrame(np.random.randn(30, 9), columns=map(str, range(9)))
# ---> 17 draw_scatterplot(df, df.columns, 3, 3)
#      18 plt.show()
#      19 #a=df['Cement']
#
# <ipython-input-9-d72359fd7018> in draw_scatterplot(df, variables, n_rows, n_cols)
#       8         y=df['Concrete compressive strength']
#       9         ax=fig.add_subplot(n_rows,n_cols,i+1)
# ---> 10         matplotlib.pyplot.scatter(i,y)
#      11         ax.set_title(var_name+" Distribution")
#      12         #df[var_name].scatter(y,ax=ax)
#
# /Users/akewakjeba/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
# ...

# %%
fig, axes = plt.subplots(1,len(df.columns.values)-1, sharey=True)

for i, col in enumerate(df.columns.values[:-1]):
    
    df.plot(x=[col], y=(["Concrete compressive strength"],ylabelsize=20), kind="scatter", ax=axes[i])
    
plt.show()
# Out:
#   File "<ipython-input-223-ab70d9da6cf4>", line 5
#     df.plot(x=[col], y=(["Concrete compressive strength"],ylabelsize=20), kind="scatter", ax=axes[i])
#                                                                     ^
# SyntaxError: invalid syntax

# %%
b=df['Blast Furnace Slag']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(b,y)
matplotlib.pyplot.show()

# %%
c=df['Fly Ash']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(c,y)
matplotlib.pyplot.show()

# %%
d=df['Water']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(d,y)
matplotlib.pyplot.show()

# %%
e=df['Superplasticizer']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(e,y)
matplotlib.pyplot.show()

# %%
f=df['Coarse Aggregate']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(f,y)
matplotlib.pyplot.show()

# %%
g=df['Fine Aggregate']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(g,y)
matplotlib.pyplot.show()

# %%
h=df['Age (day)']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(h,y)
matplotlib.pyplot.show()

# %%
i=df['Concrete compressive strength']
y=df['Concrete compressive strength']
matplotlib.pyplot.scatter(i,y)
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.scatter(a,c)
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-72b247422bf1> in <module>()
# ----> 1 matplotlib.pyplot.scatter(a,c)
#       2 matplotlib.pyplot.show()
#
# NameError: name 'a' is not defined

# %%
for label, x, y in zip(b, pca.Y[:,0], pca.Y[:,1]):
    matplotlib.pyplot.annotate( label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom' )
matplotlib.pyplot.show()

# %%
#from matplotlib.mlab import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (1030, 9)

# %%
x_pca.shape
# Out:
# (1030, 2)

# %%
df.keys()
# Out:
# Index([u'Cement', u'Blast Furnace Slag', u'Fly Ash', u'Water',
#        u'Superplasticizer', u'Coarse Aggregate', u'Fine Aggregate',
#        u'Age (day)', u'Concrete compressive strength'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Concrete compressive strength'])
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')

# %%
pca.components_
# Out:
# array([[ 0.04106772,  0.16299258, -0.36981124,  0.56408457, -0.53605897,
#          0.06045806, -0.3816834 ,  0.26191454, -0.10723462],
#        [ 0.53647276,  0.13630059, -0.26840644, -0.11812787,  0.24823122,
#         -0.22483096, -0.18706198,  0.25182948,  0.63011502]])

# %%
df_comp = pd.DataFrame(df,df['Cement'])

# %%
import seaborn as sns

# %%
sns.heatmap(df,cmap='plasma')

# %%
from sklearn import manifold
from sklearn.manifold import MDS

# %%
adist = np.array(df)

# %%
adist.shape
# Out:
# (1030, 9)

# %%
mds = MDS(n_components=2)

# %%
mds1=mds.fit_transform(adist)

# %%
mds1.shape
type(mds1)
# Out:
# numpy.ndarray

# %%
#x_pca = pca.transform(scaled_data)
#adist=x_pca.shape
#adist = np.array(mds1)
#mds = manifold.MDS(n_components=2, dissimilarity="precomputed", random_state=6)
results = mds.fit(mds1)

coords = results.embedding_
plt.subplot()
#plt.subplots_adjust(bottom = 0.1)
#plt.scatter(coords[:, 0], coords[:, 1], marker = 'o')
plt.scatter(coords[:,0],coords[:,1],c=df['Concrete compressive strength'])
plt.show()

# %%
mds2 = manifold.MDS(n_components=2)
embed2d = mds2.fit(mds1).embedding_
subpl2 = fig.add_subplot(133)
subpl2.set_autoscaley_on(False)
subpl2.scatter(embed2d[:, 0], embed2d[:, 1],s=20)
plt.title('2D Multidim. Scaling Embedding')
plt.axis('tight')

plt.show()

# %%
plt.subplots_adjust(bottom = 0.1)
plt.scatter(coords[:, 0], coords[:, 1], marker = 'o')
plt.show()

# %%
import scipy
from scipy.stats import spearmanr, kendalltau, pearsonr

# %%
b.corr(y)
# Out:
# 0.13482444514334266

# %%
print scipy.stats.stats.kendalltau(b, y)[0]
# Out:
# 0.118004980822

# %%
print scipy.stats.stats.spearmanr(b, y)[0]
# Out:
# 0.162473431804

# %%
for i, col in enumerate(df.columns.values[:-1]):
    print scipy.stats.stats.spearmanr(( col), y)[0]
    
    #df.plot(x=[col], y=["Concrete compressive strength"], kind="scatter", ax=axes[i])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
parameter = [a, b]#, c, d, e, f, g, h, i]
kendalltau(parameter, df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-6ecac8de58fd> in <module>()
#       1 parameter = [a, b]#, c, d, e, f, g, h, i]
# ----> 2 kendalltau(parameter, df)
#
# /Users/akewakjeba/anaconda/lib/python2.7/site-packages/scipy/stats/stats.pyc in kendalltau(x, y, initial_lexsort, nan_policy)
#    3494     if x.size != y.size:
#    3495         raise ValueError("All inputs to `kendalltau` must be of the same size, "
# -> 3496                          "found x-size %s and y-size %s" % (x.size, y.size))
#    3497     elif not x.size or not y.size:
#    3498         return KendalltauResult(np.nan, np.nan)  # Return NaN if arrays are empty
#
# ValueError: All inputs to `kendalltau` must be of the same size, found x-size 2060 and y-size 9270

# %%
df
